# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
filename = 'ca-500.csv'

# %%
df = pd.read_csv(filename, sep=';')
df
# Out:
#     first_name      last_name                    company_name  \
# 0    Francoise  Rautenstrauch               Riebesell, H F Jr
# 1       Kendra           Loud               Deloitte & Touche
# 2      Lourdes       Bauswell               Oklahoma Neon Inc
# 3       Hannah        Edmison              M B A Paint Stores
# 4          Tom          Loeza       Sheraton Shreveport Hotel
# ..         ...            ...                             ...
# 495       Erin      Delbosque             Curtiss Wright Corp
# 496  Kassandra       Marushia        Phelps Tool & Die Co Inc
# 497     Leslee        Matsuno         Factory Mattress Outlet
# 498     Daniel         Dobler  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio          Unruh      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    500 non-null    object
#  1   last_name     500 non-null    object
#  2   company_name  500 non-null    object
#  3   address       500 non-null    object
#  4   city          500 non-null    object
#  5   province      500 non-null    object
#  6   postal        500 non-null    object
#  7   phone1        500 non-null    object
#  8   phone2        500 non-null    object
#  9   email         500 non-null    object
#  10  web           500 non-null    object
# dtypes: object(11)
# memory usage: 43.1+ KB

# %%
df['city'].value_counts().head(10)
# Out:
# city
# Calgary       19
# Montreal      12
# Etobicoke     11
# Surrey         9
# Vancouver      9
# Regina         9
# North York     9
# Edmonton       9
# Quebec         8
# Toronto        7
# Name: count, dtype: int64

# %%
df.query('city=="Montreal"').sort_values('last_name')
# Out:
#     first_name   last_name                   company_name  \
# 315        Val      Bigaud               Mpsi Systems Inc
# 109      Tesha       Brang       Butler Tool & Design Inc
# 67      Mammie      Cisney         Arellano, Cecilia S Md
# 236     Maddie      Foulds  Sinclair Machine Products Inc
# 422     Verona       Jobst               M C Green & Sons
# 239  Steffanie      Meinen          Rosenblum, Donn D Esq
# 411      Luann      Michon    Macnaughton Einson Graphics
# 483  Clemencia  Momplaisir       Computer System Dynamics
# 424      Rikki    Montalgo           Emergency Management
# 233     Harris       Sheck           New Lans Corporation
# 468      Ricki       Traux       Collins, Frederick H Esq
# 350      Denny      Zeanah         Associated Brokers Inc
#
#                    address      city province   postal        phone1  \
# 315      42 N 16th St #620  Montreal       QC  H2C 3A1  514-726-2573
# ...

# %%
df['province'].value_counts()
# Out:
# province
# ON    175
# QC    116
# BC     72
# AB     42
# NB     30
# NS     23
# SK     21
# MB     12
# NL      8
# PE      1
# Name: count, dtype: int64

# %%
df['province'].value_counts().plot(kind='barh')
# Out:
# <Axes: ylabel='province'>

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df[['first_name', 'last_name', 'city']].query('city in ["Montreal", "Toronto"]').sort_values(['city','last_name'])
# Out:
#     first_name   last_name      city
# 315        Val      Bigaud  Montreal
# 109      Tesha       Brang  Montreal
# 67      Mammie      Cisney  Montreal
# 236     Maddie      Foulds  Montreal
# 422     Verona       Jobst  Montreal
# 239  Steffanie      Meinen  Montreal
# 411      Luann      Michon  Montreal
# 483  Clemencia  Momplaisir  Montreal
# 424      Rikki    Montalgo  Montreal
# 233     Harris       Sheck  Montreal
# 468      Ricki       Traux  Montreal
# 350      Denny      Zeanah  Montreal
# 264      Floyd         Bub   Toronto
# 409    Timothy     Bussert   Toronto
# 105   Herschel     Geneseo   Toronto
# 412      Mable      Goerke   Toronto
# 71       Coral    Helmcamp   Toronto
# 124     Makeda       Nosis   Toronto
# 121      India     Sifford   Toronto

# %%
df['n'] = df['last_name'].str.len()

# %%
df
# Out:
#     first_name      last_name                    company_name  \
# 0    Francoise  Rautenstrauch               Riebesell, H F Jr
# 1       Kendra           Loud               Deloitte & Touche
# 2      Lourdes       Bauswell               Oklahoma Neon Inc
# 3       Hannah        Edmison              M B A Paint Stores
# 4          Tom          Loeza       Sheraton Shreveport Hotel
# ..         ...            ...                             ...
# 495       Erin      Delbosque             Curtiss Wright Corp
# 496  Kassandra       Marushia        Phelps Tool & Die Co Inc
# 497     Leslee        Matsuno         Factory Mattress Outlet
# 498     Daniel         Dobler  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio          Unruh      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    500 non-null    object
#  1   last_name     500 non-null    object
#  2   company_name  500 non-null    object
#  3   address       500 non-null    object
#  4   city          500 non-null    object
#  5   province      500 non-null    object
#  6   postal        500 non-null    object
#  7   phone1        500 non-null    object
#  8   phone2        500 non-null    object
#  9   email         500 non-null    object
#  10  web           500 non-null    object
#  11  n             500 non-null    int64
# dtypes: int64(1), object(11)
# memory usage: 47.0+ KB

# %%
a = df['n'].values

# %%
type(a)
# Out:
# numpy.ndarray

# %%
url = 'https://nl.wikipedia.org/wiki/Provincies_van_Nederland'
list_of_dfs = pd.read_html(url, decimal=',', thousands='.')
df = list_of_dfs[0]
df
# Out:
#     Vlag            Provincie  Bevolking[1]  Oppervlakte (land+water) in km²  \
# 0    NaN            Groningen        596163                          2959.68
# 1    NaN  Fryslân (Friesland)        659612                          5748.77
# 2    NaN              Drenthe        502120                          2680.39
# 3    NaN           Overijssel       1184551                          3420.74
# 4    NaN            Flevoland        444850                          2412.31
# 5    NaN           Gelderland       2133751                          5136.31
# 6    NaN              Utrecht       1387657                          1560.05
# 7    NaN        Noord-Holland       2956223                          4091.93
# 8    NaN         Zuid-Holland       3804737                          3307.86
# 9    NaN              Zeeland        391142                          2933.44
# 10   NaN        Noord-Brabant       2626368                          5082.06
# ...

# %%
# !conda install lxml -y
# Out:
# Channels:
#  - conda-forge
# Platform: osx-arm64
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/homebrew/Caskroom/miniforge/base
#
#   added / updated specs:
#     - lxml
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     libxslt-1.1.39             |       h223e5b9_0         220 KB  conda-forge
#     lxml-5.3.0                 |  py311h96511b9_1         1.1 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   libxslt            conda-forge/osx-arm64::libxslt-1.1.39-h223e5b9_0
#   lxml               conda-forge/osx-arm64::lxml-5.3.0-py311h96511b9_1
#
#
#
# ...
# lxml-5.3.0           | 1.1 MB    |                                       |   0%
# ...

# %%
import requests

# %%
city = 'Eindhoven'
url = 'https://api.openweathermap.org/data/2.5/weather?appid=d1526a9039658a6f76950cff21823aff&units=metric&mode=json&q=' + city
url
# Out:
# 'https://api.openweathermap.org/data/2.5/weather?appid=d1526a9039658a6f76950cff21823aff&units=metric&mode=json&q=Eindhoven'

# %%
r = requests.get(url)

# %%
r.status_code
# Out:
# 200

# %%
d = r.json()

# %%
temperature = d['main']['temp']
print(temperature)
# Out:
# 12.86
