# %%
import numpy as np
import pandas as pd

# %%
filename = '../Sandbox/ca-500.csv'

# %%
df = pd.read_csv(filename, sep=';')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   first_name    500 non-null    object
#  1   last_name     500 non-null    object
#  2   company_name  500 non-null    object
#  3   address       500 non-null    object
#  4   city          500 non-null    object
#  5   province      500 non-null    object
#  6   postal        500 non-null    object
#  7   phone1        500 non-null    object
#  8   phone2        500 non-null    object
#  9   email         500 non-null    object
#  10  web           500 non-null    object
# dtypes: object(11)
# memory usage: 43.1+ KB

# %%
df
# Out:
#     first_name      last_name                    company_name  \
# 0    Francoise  Rautenstrauch               Riebesell, H F Jr
# 1       Kendra           Loud               Deloitte & Touche
# 2      Lourdes       Bauswell               Oklahoma Neon Inc
# 3       Hannah        Edmison              M B A Paint Stores
# 4          Tom          Loeza       Sheraton Shreveport Hotel
# ..         ...            ...                             ...
# 495       Erin      Delbosque             Curtiss Wright Corp
# 496  Kassandra       Marushia        Phelps Tool & Die Co Inc
# 497     Leslee        Matsuno         Factory Mattress Outlet
# 498     Daniel         Dobler  Cosgroves N End Plbg & Hdwr Co
# 499    Antonio          Unruh      Mission Lincoln Properties
#
#                     address            city province   postal        phone1  \
# 0        2335 Canton Hwy #6         Windsor       ON  N8N 3N2  519-569-8399
# ...

# %%
df['fullname'] = df['first_name'] + ' ' + df['last_name']
df[['first_name', 'last_name', 'fullname', 'city']].query('city=="Montreal"')
# Out:
#     first_name   last_name              fullname      city
# 67      Mammie      Cisney         Mammie Cisney  Montreal
# 109      Tesha       Brang           Tesha Brang  Montreal
# 233     Harris       Sheck          Harris Sheck  Montreal
# 236     Maddie      Foulds         Maddie Foulds  Montreal
# 239  Steffanie      Meinen      Steffanie Meinen  Montreal
# 315        Val      Bigaud            Val Bigaud  Montreal
# 350      Denny      Zeanah          Denny Zeanah  Montreal
# 411      Luann      Michon          Luann Michon  Montreal
# 422     Verona       Jobst          Verona Jobst  Montreal
# 424      Rikki    Montalgo        Rikki Montalgo  Montreal
# 468      Ricki       Traux           Ricki Traux  Montreal
# 483  Clemencia  Momplaisir  Clemencia Momplaisir  Montreal

# %%
df[['first_name','last_name','city','email']].query('city in ("Montreal", "Toronto")').sort_values(['city', 'last_name'])
# Out:
#     first_name   last_name      city                        email
# 315        Val      Bigaud  Montreal           val_bigaud@aol.com
# 109      Tesha       Brang  Montreal                tesha@aol.com
# 67      Mammie      Cisney  Montreal               mammie@cox.net
# 236     Maddie      Foulds  Montreal           maddie@hotmail.com
# 422     Verona       Jobst  Montreal       verona_jobst@jobst.org
# 239  Steffanie      Meinen  Montreal     steffanie.meinen@cox.net
# 411      Luann      Michon  Montreal                luann@cox.net
# 483  Clemencia  Momplaisir  Montreal        cmomplaisir@yahoo.com
# 424      Rikki    Montalgo  Montreal           rikki@montalgo.com
# 233     Harris       Sheck  Montreal               harris@cox.net
# 468      Ricki       Traux  Montreal        ricki.traux@traux.com
# 350      Denny      Zeanah  Montreal      denny_zeanah@zeanah.com
# 264      Floyd         Bub   Toronto                 fbub@bub.com
# ...

# %%
df['province'].value_counts().plot(kind='barh');

# %%
pd.set_option('display.max_rows', 1000)

# %%
df[['province','city', 'first_name', 'last_name']].groupby(['province', 'city']).agg(func=('min','max')).reset_index()
# Out:
#     province                      city  first_name                 last_name  \
#                                                min         max           min
# 0         AB                Big Valley      Yvette      Yvette        Capiga
# 1         AB                   Calgary      Blythe        Susy       Airhart
# 2         AB                   Camrose        Noel        Noel      Marrazzo
# 3         AB                  Edmonton      Cletus      Tamera         Ancar
# 4         AB             Fort McMurray    Herminia    Herminia         Penso
# 5         AB            Grande Prairie       Paola       Paola       Perkins
# 6         AB                     Leduc     Willard     Willard       Lablanc
# 7         AB                Lethbridge     Nakisha     Phyliss        Huelse
# 8         AB              Lloydminster        Shad        Shad        Reider
# 9         AB                  Red Deer      Danilo      Nguyet      Kitchens
# ...

# %%
df.value_counts('province')
# Out:
# province
# ON    175
# QC    116
# BC     72
# AB     42
# NB     30
# NS     23
# SK     21
# MB     12
# NL      8
# PE      1
# Name: count, dtype: int64

# %%
df['first_name'].apply(len)
# Out:
# 0       9
# 1       6
# 2       7
# 3       6
# 4       3
# 5       7
# 6       3
# 7       6
# 8       3
# 9       5
# 10      9
# 11      6
# 12      6
# 13      4
# 14      8
# 15      7
# 16      6
# 17      6
# 18      8
# 19      5
# 20      7
# 21      6
# 22      7
# 23      5
# 24      6
# 25      9
# 26      4
# 27      6
# 28      6
# 29      4
# 30      6
# 31      4
# 32      6
# 33      6
# 34      5
# 35      6
# 36      6
# 37      6
# 38      7
# 39      5
# 40      5
# 41      9
# 42      7
# 43      6
# 44      4
# 45      8
# 46      8
# 47      5
# 48      4
# 49      4
# 50      7
# 51      5
# 52      6
# 53      5
# 54      6
# 55      6
# 56      5
# 57      6
# 58      5
# 59      6
# 60      5
# 61      4
# 62      4
# 63      7
# 64      5
# 65      6
# 66      7
# 67      6
# 68      6
# 69      5
# 70      6
# 71      5
# 72      5
# 73      6
# 74     10
# 75      6
# 76      8
# 77      6
# 78      7
# 79      5
# 80      5
# 81      3
# 82      9
# ...

# %%
df['first_name'].transform(len)
# Out:
# 0       9
# 1       6
# 2       7
# 3       6
# 4       3
# 5       7
# 6       3
# 7       6
# 8       3
# 9       5
# 10      9
# 11      6
# 12      6
# 13      4
# 14      8
# 15      7
# 16      6
# 17      6
# 18      8
# 19      5
# 20      7
# 21      6
# 22      7
# 23      5
# 24      6
# 25      9
# 26      4
# 27      6
# 28      6
# 29      4
# 30      6
# 31      4
# 32      6
# 33      6
# 34      5
# 35      6
# 36      6
# 37      6
# 38      7
# 39      5
# 40      5
# 41      9
# 42      7
# 43      6
# 44      4
# 45      8
# 46      8
# 47      5
# 48      4
# 49      4
# 50      7
# 51      5
# 52      6
# 53      5
# 54      6
# 55      6
# 56      5
# 57      6
# 58      5
# 59      6
# 60      5
# 61      4
# 62      4
# 63      7
# 64      5
# 65      6
# 66      7
# 67      6
# 68      6
# 69      5
# 70      6
# 71      5
# 72      5
# 73      6
# 74     10
# 75      6
# 76      8
# 77      6
# 78      7
# 79      5
# 80      5
# 81      3
# 82      9
# ...

# %%
df = pd.DataFrame({'A': range(3), 'B': range(1, 4)})
df
# Out:
#    A  B
# 0  0  1
# 1  1  2
# 2  2  3

# %%
df.transform(np.sqrt)
# Out:
#           A         B
# 0  0.000000  1.000000
# 1  1.000000  1.414214
# 2  1.414214  1.732051
