# %% [markdown]
# # Openweathermap

# %%
import requests

# %%
city = 'Eindhoven'

url = "http://api.openweathermap.org/data/2.5/weather"
url += "?appid=d1526a9039658a6f76950cff21823aff"
url += "&units=metric"
url += "&mode=json"
url += "&q=" + city

# %%
url
# Out:
# 'http://api.openweathermap.org/data/2.5/weather?appid=d1526a9039658a6f76950cff21823aff&units=metric&mode=json&q=Eindhoven'

# %%
response = requests.get(url)

if (response.status_code == 200):
    body = response.text
    decoded = response.json()
    temperature = decoded['main']['temp']
else:
    print("Error for city %s" % (city))

# %%
print(f'The temperature in {city} in {temperature:.0f} degrees')
# Out:
# The temperature in Eindhoven in 7 degrees
